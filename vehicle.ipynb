# %%
import numpy as np
import pandas as pd 
import seaborn as sns
cars_df = pd.read_csv(r'E:\41TS\cars (1).csv')
cars_df.head()
# Out:
#     mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year     brand
# 0  14.0           8          350  165       4209           12   1972       US.
# 1  31.9           4           89   71       1925           14   1980   Europe.
# 2  17.0           8          302  140       3449           11   1971       US.
# 3  15.0           8          400  150       3761           10   1971       US.
# 4  30.5           4           98   63       2051           17   1978       US.

# %%
cars_df.columns = cars_df.columns.str.strip()

# Convert 'year' to numeric
cars_df['year'] = pd.to_numeric(cars_df['year'])

# Group by year and calculate the mean mpg
mpg_trend = cars_df.groupby('year')['mpg'].mean()

# Plot the mpg trend over the years
plt.figure(figsize=(10, 5))
plt.plot(mpg_trend.index, mpg_trend.values, marker='o', linestyle='-', color='b', label='Avg MPG')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Average MPG")
plt.title("Trend of MPG Over the Years")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Group by brand and calculate the mean horsepower
hp_by_brand = cars_df.groupby('brand')['hp'].mean()

# Plot the mean horsepower by brand
plt.figure(figsize=(10, 5))
hp_by_brand.plot(kind='bar', color='skyblue')

# Labels and title
plt.xlabel("Brand")
plt.ylabel("Average Horsepower")
plt.title("Average Horsepower by Brand")

# Show the plot
plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Scatter plot of cubic inches vs time-to-60
plt.figure(figsize=(10, 5))
sns.scatterplot(x='cubicinches', y='time-to-60', data=cars_df_clean)

# Labels and title
plt.xlabel("Cubic Inches")
plt.ylabel("Time to 60 mph (seconds)")
plt.title("Cubic Inches vs Time to 60 mph")

# Show the plot
plt.show()

# Calculate the correlation coefficient
correlation = cars_df_clean['cubicinches'].corr(cars_df_clean['time-to-60'])
print(f"Correlation coefficient between cubic inches and time-to-60: {correlation}")
# Out:
# Correlation coefficient between cubic inches and time-to-60: -0.6131991064296582

# %%
# Create a scatter plot with a regression line to show the relationship between horsepower and mpg
plt.figure(figsize=(10, 6))
sns.regplot(data=cars_df_clean, x='hp', y='mpg', scatter_kws={'s':10}, line_kws={'color':'red'})
plt.title('Effect of Horsepower on MPG')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.grid(True)
plt.show()

# %%
# Create a scatter plot with a regression line to show the relationship between horsepower and mpg
plt.figure(figsize=(10, 6))
sns.regplot(data=cars_df_clean, x='hp', y='mpg', scatter_kws={'s':10}, line_kws={'color':'red'})
plt.title('Effect of Horsepower on MPG')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.grid(True)
plt.show()

# %%
# Create a scatter plot with a regression line to show the relationship between cubic inches and mpg
plt.figure(figsize=(10, 6))
sns.regplot(data=cars_df_clean, x='cubicinches', y='mpg', scatter_kws={'s':10}, line_kws={'color':'red'})
plt.title('Effect of Cubic Inches on MPG')
plt.xlabel('Cubic Inches')
plt.ylabel('MPG')
plt.grid(True)
plt.show()

# Calculate the correlation coefficient
correlation_cubic_inches_mpg = cars_df_clean['cubicinches'].corr(cars_df_clean['mpg'])
print(f"Correlation coefficient between cubic inches and mpg: {correlation_cubic_inches_mpg}")
# Out:
# Correlation coefficient between cubic inches and mpg: -0.803963576335497

# %%
# Create a pair plot to observe the relationships between cubic inches, number of cylinders, and horsepower
sns.pairplot(cars_df_clean, vars=['cubicinches', 'cylinders', 'hp'], kind='reg', diag_kind='kde')

# Show the plot
plt.show()
